# %%
 import pandas as pd
from sqlalchemy import create_engine

# %%
#Extract CSVs into DataFrames

crime_file = "C:/Users/Owner/desktop/ETL-Project/Resources/crime_by_state.csv"
crime_df = pd.read_csv(crime_file)
crime_df
# Out:
#               STATE/UT    Year  Murder  Assault on women  \
# 0                  NaN     NaN     NaN               NaN
# 1       ANDHRA PRADESH  2001.0    45.0              69.0
# 2                  NaN     NaN     NaN               NaN
# 3       ANDHRA PRADESH  2002.0    60.0              98.0
# 4                  NaN     NaN     NaN               NaN
# ..                 ...     ...     ...               ...
# 907  TOTAL (ALL-INDIA)  2010.0   572.0            1350.0
# 908                NaN     NaN     NaN               NaN
# 909  TOTAL (ALL-INDIA)  2011.0   673.0            1557.0
# 910                NaN     NaN     NaN               NaN
# 911  TOTAL (ALL-INDIA)  2012.0   651.0            1576.0
#
#      Kidnapping and Abduction  Dacoity  Robbery  Arson    Hurt  \
# 0                         NaN      NaN      NaN    NaN     NaN
# 1                        22.0      3.0      2.0    6.0   518.0
# 2                         NaN      NaN      NaN    NaN     NaN
# 3                        18.0      0.0      4.0   12.0   568.0
# 4                         NaN      NaN      NaN    NaN     NaN
# ..                        ...      ...      ...    ...     ...
# 907                     510.0     41.0     75.0  150.0  4344.0
# 908                       NaN      NaN      NaN    NaN     NaN
# 909                     616.0     36.0     54.0  169.0  4247.0
# 910                       NaN      NaN      NaN    NaN     NaN
# 911                     490.0     27.0     40.0  214.0  3855.0
#
#      Prevention of atrocities (POA) Act  Protection of Civil Rights (PCR) Act  \
# 0                                   NaN                                   NaN
# 1                                 950.0                                 312.0
# 2                                   NaN                                   NaN
# 3                                 830.0                                 459.0
# 4                                   NaN                                   NaN
# ..                                  ...                                   ...
# 907                             10419.0                                 143.0
# 908                                 NaN                                   NaN
# 909                             11342.0                                  67.0
# 910                                 NaN                                   NaN
# 911                             12576.0                                  62.0
#
#      Other Crimes Against SCs
# 0                         NaN
# 1                      1006.0
# 2                         NaN
# 3                      1336.0
# 4                         NaN
# ..                        ...
# 907                   15039.0
# 908                       NaN
# 909                   14958.0
# 910                       NaN
# 911                   14164.0
#
# [912 rows x 12 columns]

# %%
#Create a filtered dataframe from specific columns
crime_cols = ["STATE/UT", "Year", "Murder", "Assault on women", "Kidnapping and Abduction", "Dacoity", "Robbery", "Arson", "Hurt", "Prevention of atrocities (POA) Act", "Protection of Civil Rights (PCR) Act", "Other Crimes Against SCs"]
crime_transformed= crime_df[crime_cols].copy()

# %%
#Rename the column headers
crime_transformed = crime_transformed.rename(columns={"STATE/UT": "State",
                                                    "Year": "Year (Count)",
                                                    "Murder (Count)": "Murder",
                                                    "Assault on women": "Assault on Women",
                                                    "Kidnapping and Abduction": "Kidnapping And Abduction",
                                                    "Dacoity": "Dacoity (Count)",
                                                    "Robbery": "Robbery (#)",
                                                    "Arson": "Arson (#)",
                                                    "Hurt": "Hurt (#)",
                                                    "Prevention of atrocities (POA) Act": "POA Act",
                                                    "Protection of Civil Rights (PCR) Act": "PCR Act",
                                                    "Other Crimes Against SCs": "Other Crimes Against SC's"})

#Clean the data by dropping duplicates setting the index
crime_transformed.drop_duplicates("State", inplace=True)
crime_transformed.set_index("State", inplace=True)

crime_transformed.head()
# Out:
#                    Year (Count)  Murder  Assault on Women  \
# State
# NaN                         NaN     NaN               NaN
# ANDHRA PRADESH           2001.0    45.0              69.0
# ARUNACHAL PRADESH        2001.0     0.0               0.0
# ASSAM                    2001.0     0.0               0.0
# BIHAR                    2001.0    28.0              35.0
#
#                    Kidnapping And Abduction  Dacoity (Count)  Robbery (#)  \
# State
# NaN                                     NaN              NaN          NaN
# ANDHRA PRADESH                         22.0              3.0          2.0
# ARUNACHAL PRADESH                       0.0              0.0          0.0
# ASSAM                                   0.0              0.0          1.0
# BIHAR                                   8.0              2.0          1.0
#
#                    Arson (#)  Hurt (#)  POA Act  PCR Act  \
# State
# NaN                      NaN       NaN      NaN      NaN
# ANDHRA PRADESH           6.0     518.0    950.0    312.0
# ARUNACHAL PRADESH        0.0       0.0      0.0      0.0
# ASSAM                    1.0       4.0      0.0      0.0
# BIHAR                   17.0     378.0    513.0     81.0
#
#                    Other Crimes Against SC's
# State
# NaN                                      NaN
# ANDHRA PRADESH                        1006.0
# ARUNACHAL PRADESH                        0.0
# ASSAM                                    0.0
# BIHAR                                  240.0

# %%
#Create database connection
connection_string = "postgres:postgres@localhost:5432/crime_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
#confirm tables
engine.tables_names()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c290beaf2ecd> in <module>
#       1 #confirm tables
# ----> 2 engine.tables_names()
#
# AttributeError: 'Engine' object has no attribute 'tables_names'

# %%
#Load Dataframes into Database
crime_transformed.to_sql(name='crime', con=engine, if_exists='append', index=True)
